# %%
# DBTITLE 1,Install Required Libraries

# %pip install azure-eventhub
# %pip install azure-storage
# %pip install azure-servicebus==0.50.3
# %pip install avro

# %%
import uuid
import datetime
import random
import json
from azure.servicebus.control_client import ServiceBusService

# event hub creds
az_service_namespace = '<event_hub_namespace>'
az_shared_access_key_name = 'RootManageSharedAccessKey'
az_shared_access_key_value = '<Event_Hub_Primary_key>'


sbs = ServiceBusService(service_namespace=az_service_namespace, shared_access_key_name=az_shared_access_key_name, shared_access_key_value=az_shared_access_key_value)
devices = []
for x in range(0, 10):
    devices.append(str(uuid.uuid4()))

for y in range(0,100000):
    for dev in devices:
        reading = {'source': 'wind-turbine-geo-sensor', 
                   'id': 'tst_sensor', 
                   'timestamp': str(datetime.datetime.utcnow()),
                   'Export_Unit': random.random(),
                   'battery_current': random.randint(10, 20), 
                   'solar_KWH': random.randint(10, 20),
                   'Grid_VOLTAGE': random.randint(250, 800),
                   'turbine_RPM': random.randint(400, 500)}
        s = json.dumps(reading)
        sbs.send_event('<event_hub_name>', s)
    print (y)
    print (s)

# %% [markdown]
# # DBTITLE 1, To remove DBFS files or folders
#
# * *dbutils.fs.rm('/path_of_folder/', True)*
